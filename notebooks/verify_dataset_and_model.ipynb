# %% [markdown]
# # Verify BCI IV-2a dataset and ATCNet shapes
#
# Run from project root `atcnet_implementation/`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd()
if (ROOT / "src").exists() is False and (ROOT.parent / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
print("Project root:", ROOT)

# %%
from src.data_loader import validate_dataset_files, load_bci2a_subject, validate_shapes

validate_dataset_files()
X, y = load_bci2a_subject(1, "T")
validate_shapes(X, y)
print("X:", X.shape, "y:", y.shape, "labels:", set(y))

# %%
import numpy as np
from src.atcnet import build_atcnet
from src.preprocessing import prepare_input
from src.train_utils import compile_model

model = build_atcnet()
compile_model(model)
model.summary()
Xb = prepare_input(X[:4])
print(model.predict(Xb, verbose=0).shape)
